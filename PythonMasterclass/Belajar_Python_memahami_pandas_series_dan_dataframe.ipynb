# %% [markdown]
# <a href="https://colab.research.google.com/github/idarwati/BelajarPython/blob/main/PythonMasterclass/Belajar_Python_memahami_pandas_series_dan_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
label = ['satu','dua','tiga']

# %%
angka = [10,20,30]

# %%
np_angka = np.array(angka)

# %%
np_angka
# Out:
# array([10, 20, 30])

# %%
d = {'satu':10, 'dua':20, 'tiga':30}

# %%
dataku = pd.Series(data=angka, index=label)

# %%
dataku['satu']
# Out:
# np.int64(10)

# %%
np_angka[0]
# Out:
# np.int64(10)

# %%
pd.Series(d)
# Out:
# satu    10
# dua     20
# tiga    30
# dtype: int64

# %%
pd.Series(np_angka)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(angka)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
dataku
# Out:
# satu    10
# dua     20
# tiga    30
# dtype: int64

# %%
dataku.to_frame()
# Out:
#        0
# satu  10
# dua   20
# tiga  30

# %%
dataku = dataku.to_frame

# %%
d2 = {'satu':10, 'dua':20, 'tiga':30, 'empat':40, 'lima':50}

# %%
dataku = pd.Series(d)

# %%
dataku2 = pd.Series(d2)

# %%
dataku
# Out:
# satu    10
# dua     20
# tiga    30
# dtype: int64

# %%
dataku2
# Out:
# satu     10
# dua      20
# tiga     30
# empat    40
# lima     50
# dtype: int64

# %%
dataku + dataku2
# Out:
# dua      40.0
# empat     NaN
# lima      NaN
# satu     20.0
# tiga     60.0
# dtype: float64

# %% [markdown]
# DataFrame

# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(100)

# %%
dataku = pd.DataFrame(np.random.randn(3,5), ['A','B','C'], ['satu','dua','tiga','empat','lima'])

# %%
dataku
# Out:
#        satu       dua      tiga     empat      lima
# A -0.104411 -0.531280  1.029733 -0.438136 -1.118318
# B  1.618982  1.541605 -0.251879 -0.842436  0.184519
# C  0.937082  0.731000  1.361556 -0.326238  0.055676

# %%
dataku['dua']
# Out:
# A   -0.531280
# B    1.541605
# C    0.731000
# Name: dua, dtype: float64

# %%
type(dataku)
# Out:
# pandas.core.frame.DataFrame

# %%
#iloc loc

# %%
dataku['baru'] = dataku['empat'] + dataku['lima']

# %%
dataku
# Out:
#        satu       dua      tiga     empat      lima      baru
# A -0.104411 -0.531280  1.029733 -0.438136 -1.118318 -1.556454
# B  1.618982  1.541605 -0.251879 -0.842436  0.184519 -0.657917
# C  0.937082  0.731000  1.361556 -0.326238  0.055676 -0.270562

# %%
dataku.drop('tiga', axis=1)
# Out:
#        satu       dua     empat      lima      baru
# A -0.104411 -0.531280 -0.438136 -1.118318 -1.556454
# B  1.618982  1.541605 -0.842436  0.184519 -0.657917
# C  0.937082  0.731000 -0.326238  0.055676 -0.270562

# %%
dataku.drop('baru', axis=1, inplace=True) #axis=1 adalah kolom

# %%
dataku
# Out:
#        satu       dua      tiga     empat      lima
# A -0.104411 -0.531280  1.029733 -0.438136 -1.118318
# B  1.618982  1.541605 -0.251879 -0.842436  0.184519
# C  0.937082  0.731000  1.361556 -0.326238  0.055676

# %%
dataku.drop('B', axis=0, inplace=True) #axis=0 adalah baris, dalam python index adalah baris

# %%
dataku
# Out:
#        satu      dua      tiga     empat      lima
# A -0.104411 -0.53128  1.029733 -0.438136 -1.118318
# C  0.937082  0.73100  1.361556 -0.326238  0.055676

# %%
dataku.shape
# Out:
# (2, 5)

# %%
dataku < 0
# Out:
#     satu    dua   tiga  empat   lima
# A   True   True  False   True   True
# C  False  False  False   True  False

# %%
dataku_bol = dataku < 0

# %%
dataku_bol
# Out:
#     satu    dua   tiga  empat   lima
# A   True   True  False   True   True
# C  False  False  False   True  False

# %%
dataku[dataku_bol]
# Out:
#        satu      dua  tiga     empat      lima
# A -0.104411 -0.53128   NaN -0.438136 -1.118318
# C       NaN      NaN   NaN -0.326238       NaN

# %%
dataku[dataku<0]
# Out:
#        satu      dua  tiga     empat      lima
# A -0.104411 -0.53128   NaN -0.438136 -1.118318
# C       NaN      NaN   NaN -0.326238       NaN

# %%
dataku = pd.DataFrame(np.random.randn(3,5), ['A','B','C'], ['satu','dua','tiga','empat','lima'])

# %%
dataku
# Out:
#        satu       dua      tiga     empat      lima
# A  0.222400 -1.443217 -0.756352  0.816454  0.750445
# B -0.455947  1.189622 -1.690617 -1.356399 -1.232435
# C -0.544439 -0.668172  0.007315 -0.612939  1.299748

# %%
dataku[dataku['tiga']>0]
# Out:
#        satu       dua      tiga     empat      lima
# C -0.544439 -0.668172  0.007315 -0.612939  1.299748

# %%
hasil = dataku[dataku['lima']>0]

# %%
hasil
# Out:
#        satu       dua      tiga     empat      lima
# A  0.222400 -1.443217 -0.756352  0.816454  0.750445
# C -0.544439 -0.668172  0.007315 -0.612939  1.299748

# %% [markdown]
#   Data Kapal Titanic

# %%
import numpy as np
import pandas as pd

# %%
# Ganti ID dengan file kamu
file_id = '1kQHNP1cpFw-44yTaEcbLrvBKY_CtUDwj'
url = f'https://drive.google.com/uc?id={file_id}'

# %%
dataku = pd.read_csv(url)

# %%
dataku
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
age = dataku['age']

# %%
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
age.count()
# Out:
# np.int64(714)

# %%
age.mean()
# Out:
# np.float64(29.69911764705882)

# %%
age.median()
# Out:
# 28.0

# %%
age.sum()
# Out:
# np.float64(21205.17)

# %%
age.std()
# Out:
# 14.526497332334044

# %%
age_bersih = age.dropna()

# %%
age_bersih
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: age, Length: 714, dtype: float64

# %%
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
dataku2 = dataku.dropna()

# %%
dataku2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 6           0       1    male  54.0      0      0  51.8625        S    E
# 10          1       3  female   4.0      1      1  16.7000        S    G
# 11          1       1  female  58.0      0      0  26.5500        S    C
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 871         1       1  female  47.0      1      1  52.5542        S    D
# 872         0       1    male  33.0      0      0   5.0000        S    B
# 879         1       1  female  56.0      0      1  83.1583        C    C
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 889         1       1    male  26.0      0      0  30.0000        C    C
#
# [182 rows x 9 columns]

# %%
dataku3 = dataku.dropna(axis=1)

# %%
dataku3
# Out:
#      survived  pclass     sex  sibsp  parch     fare
# 0           0       3    male      1      0   7.2500
# 1           1       1  female      1      0  71.2833
# 2           1       3  female      0      0   7.9250
# 3           1       1  female      1      0  53.1000
# 4           0       3    male      0      0   8.0500
# ..        ...     ...     ...    ...    ...      ...
# 886         0       2    male      0      0  13.0000
# 887         1       1  female      0      0  30.0000
# 888         0       3  female      1      2  23.4500
# 889         1       1    male      0      0  30.0000
# 890         0       3    male      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
dataku4 = dataku.dropna(thresh=1) #data tidak akan dihapus jika dalam 1 baris  ada min 1 yang Na

# %%
dataku4
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku2 = dataku

# %%
dataku2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku2.age.fillna(value=dataku2.age.mean()) #mengisi variable yang kosong di 'age' dengan nilai rata2
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
dataku2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
dataku2.age = dataku2.age.fillna(value=dataku2.age.mean())
#gunakan mean hanya jika datanya numerik

# %%
dataku2
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.000000      1      0   7.2500        S  NaN
# 1           1       1  female  38.000000      1      0  71.2833        C    C
# 2           1       3  female  26.000000      0      0   7.9250        S  NaN
# 3           1       1  female  35.000000      1      0  53.1000        S    C
# 4           0       3    male  35.000000      0      0   8.0500        S  NaN
# ..        ...     ...     ...        ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.000000      0      0  13.0000        S  NaN
# 887         1       1  female  19.000000      0      0  30.0000        S    B
# 888         0       3  female  29.699118      1      2  23.4500        S  NaN
# 889         1       1    male  26.000000      0      0  30.0000        C    C
# 890         0       3    male  32.000000      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
type(dataku2.age)
# Out:
# pandas.core.series.Series

# %%
#klo utk machine learning data yg dibutuhkan bukan series tapi array, jadi diubah dari series ke methode

dataku2.age.values
# Out:
# array([22.        , 38.        , 26.        , 35.        , 35.        ,
#        29.69911765, 54.        ,  2.        , 27.        , 14.        ,
#         4.        , 58.        , 20.        , 39.        , 14.        ,
#        55.        ,  2.        , 29.69911765, 31.        , 29.69911765,
#        35.        , 34.        , 15.        , 28.        ,  8.        ,
#        38.        , 29.69911765, 19.        , 29.69911765, 29.69911765,
#        40.        , 29.69911765, 29.69911765, 66.        , 28.        ,
#        42.        , 29.69911765, 21.        , 18.        , 14.        ,
#        40.        , 27.        , 29.69911765,  3.        , 19.        ,
#        29.69911765, 29.69911765, 29.69911765, 29.69911765, 18.        ,
#         7.        , 21.        , 49.        , 29.        , 65.        ,
#        29.69911765, 21.        , 28.5       ,  5.        , 11.        ,
#        22.        , 38.        , 45.        ,  4.        , 29.69911765,
# ...

# %%
type(dataku2.age.values)
# Out:
# numpy.ndarray
