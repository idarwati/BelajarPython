# %% [markdown]
# <a href="https://colab.research.google.com/github/idarwati/BelajarPython/blob/main/PythonMasterclass/_37_Membuat_Plot_dengan_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Seaborn**
#
# https://seaborn.pydata.org/

# %% [markdown]
# Library Python yang khusus untuk membuat plot statistik
#
# Dibuat berdasarkan library Matplotlib
#
# Sangat cocok dipakai bersama library Pandas

# %%
import pandas as pd
import scipy.stats as stat

# %%
# Ganti ID dengan file kamu
file_id = '1kQHNP1cpFw-44yTaEcbLrvBKY_CtUDwj'
url = f'https://drive.google.com/uc?id={file_id}'

# %%
dataku = pd.read_csv(url)

# %%
dataku.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
import seaborn as sns

# %%
sns.set() # ini digunakan untuk memberitahu python bahwa kita ingin menggunakan style seaborn

# %%
# Distribution plot

sns.distplot(dataku['age']) #cara penulisan pertama
# Out:
# <ipython-input-165-d1a5f97099a5>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataku['age']) #cara penulisan pertama
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(dataku.age) # cara penulisan kedua
# kurvanya disebut Kernel Density Estimation (KDE)
# Out:
# <ipython-input-166-d3aa8ad27461>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataku.age) # cara penulisan kedua
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(dataku.age, kde=False)
# Out:
# <ipython-input-167-ac2c49019cfe>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataku.age, kde=False)
# <Axes: xlabel='age'>

# %%
sns.displot(dataku.age) # disarankan untuk menggunakan kode ini 'displot', karena kode 'distplot' sudah usang(deprecated)

# %%
sns.displot(dataku.age, kde=True)
# disarankan untuk menggunakan kode ini 'displot', karena kode 'distplot' sudah usang(deprecated).
# menambahkan kode kde=True agar memunculkan Kernel Density Estimation (kurva)

# %%
sns.histplot(dataku.age) # disarankan untuk menggunakan kode ini 'displot', karena kode 'distplot' sudah usang(deprecated)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(dataku.age, kde=True)
# disarankan untuk menggunakan kode ini 'displot', karena kode 'distplot' sudah usang(deprecated).
# menambahkan kode kde=True agar memunculkan Kernel Density Estimation (kurva)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.distplot(dataku.age, kde=False, bins=40)
# Out:
# <ipython-input-172-572a0a826550>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataku.age, kde=False, bins=40)
# <Axes: xlabel='age'>

# %%
sns.distplot(dataku.age, kde=True, bins=100)
# Out:
# <ipython-input-173-48d812eb6d82>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataku.age, kde=True, bins=100)
# <Axes: xlabel='age', ylabel='Density'>

# %%
dataku.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
sns.jointplot(x='age', y='fare', data=dataku)
# outputnya ada scatter plot karna secara default di jointpoint utk kind : {"scatter"|"reg"|"resid"|"kde"|"hex"}, optional kind of plot to draw.

# %%
sns.jointplot(x='age', y='fare', stat_func=stat.pearsonr, data=dataku)
# pada contoh latihan menggunakan kode di atas, tapi di cola.research.google.com sdh depreceated jadi fungsi ini tidak bisa berjalan
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-176-8ce2da1b56ec> in <cell line: 0>()
# ----> 1 sns.jointplot(x='age', y='fare', stat_func=stat.pearsonr, data=dataku)
#       2 # pada contoh latihan menggunakan kode di atas, tapi di cola.research.google.com sdh depreceated jadi fungsi ini tidak bisa berjalan
#
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2255
#    2256         joint_kws.setdefault("color", color)
# -> 2257         grid.plot_joint(scatterplot, **joint_kws)
#    2258
#    2259         if grid.hue is None:
#
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py in plot_joint(self, func, **kwargs)
#    1830
# ...

# %%
# data ini menggunakan source sns.load_dataset("titanic"), jadi tidak menggunakan url seperti di awal
# untuk mengatasi hal diatas, menggunakan fungsi dibawah ini.
# menggunakan kind'scatter'

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# Load data
dataku = sns.load_dataset("titanic")

# Hitung korelasi Pearson
r, p = pearsonr(df['age'], df['fare'])

# Buat jointplot
g = sns.jointplot(data=df, x="age", y="fare", kind='scatter')

# Tambahkan teks korelasi ke plot
plt.annotate(f"Pearson r = {r:.2f}\n(p = {p:.3f})",
             xy=(0.1, 0.9), xycoords='axes fraction',
             ha='left', fontsize=12)

plt.show()

# %%
# data ini menggunakan source sns.load_dataset("titanic"), jadi tidak menggunakan url seperti di awal
# untuk mengatasi hal diatas, menggunakan fungsi dibawah ini.
# menggunakan kind'scatter'

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# Load data
dataku = sns.load_dataset("titanic")

# Hitung korelasi Pearson
r, p = pearsonr(df['age'], df['fare'])

# Buat jointplot
g = sns.jointplot(data=df, x="age", y="fare", kind='scatter')

# Tambahkan teks korelasi ke plot
plt.annotate(f"Pearson r = {r:.2f}\n(p = {p:.3f})",
             xy=(0.1, 0.9), xycoords='axes fraction',
             ha='left', fontsize=12)

plt.show()

# %%
# data ini menggunakan source menggunakan url seperti di awal, menggunakan pd.read_csv
# menggunakan kind'regresi'

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# Load data
dataku = pd.read_csv(url)

# Hitung korelasi Pearson
r, p = pearsonr(df['age'], df['fare'])

# Buat jointplot
g = sns.jointplot(data=df, x="age", y="fare", kind='reg')

# Tambahkan teks korelasi ke plot
plt.annotate(f"Pearson r = {r:.3f}\n(p = {p:.3f})",
             xy=(0.1, 0.9), xycoords='axes fraction',
             ha='left', fontsize=12)

# plt.annotate adalah fungsi dari Matplotlib untuk menambahkan teks (annotasi) ke dalam plot. Cocok digunakan untuk menunjukkan nilai penting seperti korelasi, p-value, dll.
# f"Pearson r = {r:.3f}\n(p = {p:.3f})" Ini adalah f-string (formatted string) yang menampilkan teks hasil analisis statistik.
#   {r:.3f} artinya tampilkan nilai r (Pearson correlation coefficient) dengan 3 angka di belakang koma.
#   {p:.3f} artinya tampilkan p-value dengan 3 angka di belakang koma.
# \n adalah line break (baris baru), jadi teks ditampilkan dua baris:
#   Pearson r = 0.45
#   (p = 0.002)
# xy=(0.1, 0.9). Menentukan posisi teks dalam plot. (0.1, 0.9) artinya: X: 10% dari lebar gambar (kiri ke kanan), Y: 90% dari tinggi gambar (bawah ke atas). Titik (0, 0) adalah pojok kiri bawah, (1, 1) adalah pojok kanan atas.
# xycoords='axes fraction'. Menyatakan bahwa koordinat xy dihitung berdasarkan ukuran sumbu (axes), bukan dalam skala data.
# 'axes fraction' artinya: (0,0) = pojok bawah kiri sumbu, (1,1) = pojok kanan atas sumbu. Jadi ini membantu posisi teks tetap stabil, meskipun data berubah.
# ha='left'. ha adalah horizontal alignment (perataan horizontal). 'left' artinya teks rata kiri.
# fontsize=12. Ukuran font teks yang ditampilkan.

plt.show()

# %%
# data ini menggunakan source sns.load_dataset("titanic"), jadi tidak menggunakan url seperti di awal
# menggunakan kind'regresi'

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# Load data
dataku = sns.load_dataset("titanic")

# Hitung korelasi Pearson
r, p = pearsonr(df['age'], df['fare'])

# Buat jointplot
g = sns.jointplot(data=df, x="age", y="fare", kind='reg')

# Tambahkan teks korelasi ke plot
plt.annotate(f"Pearson r = {r:.3f}, (p = {p:.3f})",
             xy=(0.1, 0.7), xycoords='axes fraction',
             ha='left', fontsize=10)

# plt.annotate adalah fungsi dari Matplotlib untuk menambahkan teks (annotasi) ke dalam plot. Cocok digunakan untuk menunjukkan nilai penting seperti korelasi, p-value, dll.
# f"Pearson r = {r:.3f}\n(p = {p:.3f})" Ini adalah f-string (formatted string) yang menampilkan teks hasil analisis statistik.
#   {r:.3f} artinya tampilkan nilai r (Pearson correlation coefficient) dengan 3 angka di belakang koma.
#   {p:.3f} artinya tampilkan p-value dengan 3 angka di belakang koma.
# xy=(0.1, 0.7). Menentukan posisi teks dalam plot. (0.1, 0.7) artinya: X: 10% dari lebar gambar (kiri ke kanan), Y: 70% dari tinggi gambar (bawah ke atas). Titik (0, 0) adalah pojok kiri bawah, (1, 1) adalah pojok kanan atas.
# xycoords='axes fraction'. Menyatakan bahwa koordinat xy dihitung berdasarkan ukuran sumbu (axes), bukan dalam skala data.
# 'axes fraction' artinya: (0,0) = pojok bawah kiri sumbu, (1,1) = pojok kanan atas sumbu. Jadi ini membantu posisi teks tetap stabil, meskipun data berubah.
# ha='left'. ha adalah horizontal alignment (perataan horizontal). 'left' artinya teks rata kiri.
# fontsize=10. Ukuran font teks yang ditampilkan.

plt.show()

# %%
# data ini menggunakan url seperti di awal
# menggunakan kind'regresi'

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# Load data
dataku = pd.read_csv(url)

# Hitung korelasi Pearson
r, p = pearsonr(df['age'], df['fare'])

# Buat jointplot
g = sns.jointplot(data=df, x="age", y="fare", kind='reg')

# Tambahkan teks korelasi ke plot
plt.annotate(f"Pearson r = {r:.3f}, (p = {p:.3f})",
             xy=(0.1, 0.7), xycoords='axes fraction',
             ha='left', fontsize=10)

# plt.annotate adalah fungsi dari Matplotlib untuk menambahkan teks (annotasi) ke dalam plot. Cocok digunakan untuk menunjukkan nilai penting seperti korelasi, p-value, dll.
# f"Pearson r = {r:.3f}\n(p = {p:.3f})" Ini adalah f-string (formatted string) yang menampilkan teks hasil analisis statistik.
#   {r:.3f} artinya tampilkan nilai r (Pearson correlation coefficient) dengan 3 angka di belakang koma.
#   {p:.3f} artinya tampilkan p-value dengan 3 angka di belakang koma.
# xy=(0.1, 0.7). Menentukan posisi teks dalam plot. (0.1, 0.7) artinya: X: 10% dari lebar gambar (kiri ke kanan), Y: 70% dari tinggi gambar (bawah ke atas). Titik (0, 0) adalah pojok kiri bawah, (1, 1) adalah pojok kanan atas.
# xycoords='axes fraction'. Menyatakan bahwa koordinat xy dihitung berdasarkan ukuran sumbu (axes), bukan dalam skala data.
# 'axes fraction' artinya: (0,0) = pojok bawah kiri sumbu, (1,1) = pojok kanan atas sumbu. Jadi ini membantu posisi teks tetap stabil, meskipun data berubah.
# ha='left'. ha adalah horizontal alignment (perataan horizontal). 'left' artinya teks rata kiri.
# fontsize=10. Ukuran font teks yang ditampilkan.

plt.show()

# %%
# Versi manual outlier
dataku.fare[dataku.fare>400]
# Out:
# 258    512.3292
# 679    512.3292
# 737    512.3292
# Name: fare, dtype: float64

# %%
dataku_now = dataku_now.dropna(subset=['age', 'fare'])

# %%
# Hitung korelasi Pearson setelah outlier dibuang
r, p = pearsonr(dataku_now['age'], dataku_now['fare'])

# Buat jointplot
g = sns.jointplot(data=dataku_now, x='age', y='fare', kind='reg')

# Tambahkan label hasil korelasi ke plot
plt.annotate(f"Pearson r = {r:.2f}; p = {p:.4f}",
             xy=(0.5, 0.97), xycoords='axes fraction',
             ha='left', fontsize=9)
# Out:
# Text(0.5, 0.97, 'Pearson r = 0.10; p = 0.0074')

# %%
# versi 2 distribusi Z (normal)

from scipy.stats import zscore
import numpy as np

# %%
nilai_z = zscore(dataku.fare)

# %%
nilai_z
# Out:
# array([-5.02445171e-01,  7.86845294e-01, -4.88854258e-01,  4.20730236e-01,
#        -4.86337422e-01, -4.78116429e-01,  3.95813561e-01, -2.24083121e-01,
#        -4.24256141e-01, -4.29555021e-02, -3.12172378e-01, -1.13845709e-01,
#        -4.86337422e-01, -1.87093118e-02, -4.90279793e-01, -3.26266659e-01,
#        -6.19988892e-02, -3.86670720e-01, -2.85997284e-01, -5.02948539e-01,
#        -1.24919787e-01, -3.86670720e-01, -4.86756223e-01,  6.63597416e-02,
#        -2.24083121e-01, -1.64441595e-02, -5.02948539e-01,  4.64700108e+00,
#        -4.89776426e-01, -4.89442190e-01, -9.02720170e-02,  2.30172882e+00,
#        -4.92377828e-01, -4.37007438e-01,  1.00606170e+00,  3.98582080e-01,
#        -5.02863973e-01, -4.86337422e-01, -2.85997284e-01, -4.22073541e-01,
#        -4.57645492e-01, -2.25593223e-01, -4.89442190e-01,  1.88762532e-01,
#        -4.89776426e-01, -4.86337422e-01, -3.36334002e-01, -4.92377828e-01,
# ...

# %%
# mencari nilai absolut, artinya nilai nya minus ataupun plus jadi plus semua

nilai_z_abs = np.abs(nilai_z)

# %%
nilai_z
# Out:
# array([-5.02445171e-01,  7.86845294e-01, -4.88854258e-01,  4.20730236e-01,
#        -4.86337422e-01, -4.78116429e-01,  3.95813561e-01, -2.24083121e-01,
#        -4.24256141e-01, -4.29555021e-02, -3.12172378e-01, -1.13845709e-01,
#        -4.86337422e-01, -1.87093118e-02, -4.90279793e-01, -3.26266659e-01,
#        -6.19988892e-02, -3.86670720e-01, -2.85997284e-01, -5.02948539e-01,
#        -1.24919787e-01, -3.86670720e-01, -4.86756223e-01,  6.63597416e-02,
#        -2.24083121e-01, -1.64441595e-02, -5.02948539e-01,  4.64700108e+00,
#        -4.89776426e-01, -4.89442190e-01, -9.02720170e-02,  2.30172882e+00,
#        -4.92377828e-01, -4.37007438e-01,  1.00606170e+00,  3.98582080e-01,
#        -5.02863973e-01, -4.86337422e-01, -2.85997284e-01, -4.22073541e-01,
#        -4.57645492e-01, -2.25593223e-01, -4.89442190e-01,  1.88762532e-01,
#        -4.89776426e-01, -4.86337422e-01, -3.36334002e-01, -4.92377828e-01,
# ...

# %%
# kita filter, karena biasanya outlier nilai zscore lebih dari 3

filter_outlier = nilai_z_abs < 3 #cara penulisan pertama

# %%
filter_data = (nilai_z_abs < 3) # cara penulisan kedua

# %%
dataku_baru = dataku[filter_outlier]

# %%
dataku_baru = dataku[filter_data]

# %%
dataku_baru
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [871 rows x 9 columns]

# %%
# Hitung korelasi Pearson setelah melakukan filter outlier
r, p = pearsonr(dataku_baru['age'], dataku_baru['fare'])

# Buat jointplot
g = sns.jointplot(data=dataku_baru, x='age', y='fare', kind='reg')

# Tambahkan label hasil korelasi ke plot
plt.annotate(f"Pearson r = {r:.2f}; p = {p:.5f}",
             xy=(0.5, 0.97), xycoords='axes fraction',
             ha='left', fontsize=9)
# Out:
# Text(0.5, 0.97, 'Pearson r = nan; p = nan')

# %%
dataku_baru[['age', 'fare']].isnull().sum()
# Out:
# age     175
# fare      0
# dtype: int64

# %%
# Hitung rata-rata kolom age (tanpa NaN)
mean_age = dataku_baru['age'].mean()

# %%
# Isi NaN dengan nilai rata-rata
dataku_baru['age'] = dataku_baru['age'].fillna(mean_age)
# Out:
# <ipython-input-217-c7fb29fd71c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataku_baru['age'] = dataku_baru['age'].fillna(mean_age)

# %%
# Hitung korelasi Pearson antara age dan fare
r, p = pearsonr(dataku_baru['age'], dataku_baru['fare'])

# Tampilkan hasilnya
print(f"Pearson r = {r:.3f}, p-value = {p:.3f}")
# Out:
# Pearson r = 0.128, p-value = 0.000

# %%
# Plot jointplot
g = sns.jointplot(data=dataku_baru, x='age', y='fare', kind='reg')

# Tambahkan label Pearson r dan p-value ke plot
plt.annotate(f"Pearson r = {r:.3f}, p = {p:.4f}",
             xy=(0.7, 0.97), xycoords='axes fraction',
             ha='center', fontsize=9)
plt.show()

# %%
# Plot jointplot
g = sns.jointplot(data=dataku_baru, x='age', y='fare', kind='hex')

# Tambahkan label Pearson r dan p-value ke plot
plt.annotate(f"Pearson r = {r:.3f}, p = {p:.4f}",
             xy=(0.7, 0.97), xycoords='axes fraction',
             ha='center', fontsize=9)
# Out:
# Text(0.7, 0.97, 'Pearson r = 0.128, p = 0.0002')

# %%
# Plot jointplot
g = sns.jointplot(data=dataku_baru, x='age', y='fare', kind='kde')

# Tambahkan label Pearson r dan p-value ke plot
plt.annotate(f"Pearson r = {r:.3f}, p = {p:.4f}",
             xy=(0.7, 0.97), xycoords='axes fraction',
             ha='center', fontsize=9)
# Out:
# Text(0.7, 0.97, 'Pearson r = 0.128, p = 0.0002')

# %%
sns.pairplot(dataku)

# %%
dataku.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
sns.pairplot(dataku, hue='sex') # hue adalah pengaturan warna
